# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = '/content/drive/MyDrive/stylegan3_train/19th_Century_French/output/19th_Century_French_Scaled1024.zip'
resume_from = '/content/drive/MyDrive/fine_tune_stylegan3wikiart/19th_Century_French_Fine_Tune1/00015-stylegan3-t-19th_Century_French_Scaled1024-gpus1-batch32-gamma32/network-snapshot-000260.pkl'

# %%
# !pip install torch torchvision
# !pip install scipy numpy pillow requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 93.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 15.9 MB/s eta 0:00:00
# ...

# %%
# !python -c "import torch; print(torch.__version__)"
# !python -c "import torchvision; print(torchvision.__version__)"
# !nvcc --version
# Out:
# 2.2.1+cu121
# 0.17.1+cu121
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import torch

import sys
sys.path.insert(0, "/content/drive/MyDrive/styleGAN3_19th_Century_Landscape/stylegan3")
import dnnlib
import torch_utils

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
import torch
print(torch.__version__)
import torch
print(torch.version.cuda)
import torch
print(torch.cuda.is_available())
# Out:
# 2.2.1+cu121
# 12.1
# True

# %%
# !pip install ninja
import ninja
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/styleGAN3_19th_Century_Landscape/stylegan3
# Out:
# /content/drive/MyDrive/styleGAN3_19th_Century_Landscape/stylegan3

# %% [markdown]
# # 19th Century France

# %%
# !python train.py --outdir=/content/drive/MyDrive/fine_tune_stylegan3wikiart/19th_Century_French_Fine_Tune1 --cfg=stylegan3-t --data=$dataset_path \
    --gpus=1 --batch=32 --gamma=32 --aug=ada --mirror=1 --kimg=2500 --snap=5 --batch-gpu=4 \
    --resume=$resume_from --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9988915792636801
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
# ...

# %% [markdown]
# ## Fine Tune 19th Century Simplified Dataset

# %%
source = '/content/drive/MyDrive/resize_images/19th_Century_French_Scaled1024'
dest = '/content/drive/MyDrive/fine_tune_stylegan3wikiart/output/19th_Century_French_Scaled1024_simple.zip'

# %%
# !python /content/drive/MyDrive/stylegan3_test/stylegan3/dataset_tool.py --source=$source --dest=$dest
# Out:
# 100% 787/787 [01:12<00:00, 10.92it/s]

# %%
dataset_path = '/content/drive/MyDrive/fine_tune_stylegan3wikiart/output/19th_Century_French_Scaled1024_simple.zip'
resume_from = '/content/drive/MyDrive/fine_tune_stylegan3wikiart/19th_Century_French_Fine_Tune1/00016-stylegan3-t-19th_Century_French_Scaled1024-gpus1-batch32-gamma32/network-snapshot-000240.pkl'

# %%
# !python train.py --outdir=/content/drive/MyDrive/fine_tune_stylegan3wikiart/19th_Century_French_Fine_Tune1 --cfg=stylegan3-t --data=$dataset_path \
    --gpus=1 --batch=32 --gamma=32 --aug=ada --mirror=1 --kimg=2500 --snap=5 --batch-gpu=4 \
    --resume=$resume_from --metrics=none
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9988915792636801
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
# ...
